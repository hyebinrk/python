# %%
a = [33, 11, 22]
if a[0] < a[1] < a[2]:
    print(a[0],a[1],a[2])
elif a[0] < a[2] < a[1]:
    print(a[0],a[2],a[1])
elif a[1] < a[0] < a[2]:
    print(a[1],a[0],a[2])
elif a[1] < a[2] < a[0]:
    print(a[1],a[2],a[0])
elif a[2] < a[0] < a[1]:
    print(a[2],a[0],a[1])
elif a[2] < a[1] < a[0]:
    print(a[2],a[1],a[0])
# Out:
# 11 22 33

# %%
a = [33, 11, 22]
if a[0] < a[1] < a[2]:
    print(a[2])
elif a[0] < a[2] < a[1]:
    print(a[1])
elif a[1] < a[0] < a[2]:
    print(a[2])
elif a[1] < a[2] < a[0]:
    print(a[0])
elif a[2] < a[0] < a[1]:
    print(a[1])
elif a[2] < a[1] < a[0]:
    print(a[0])
# Out:
# 33

# %%
import random
box = ['가위','바위','보']
you = input('가위, 바위, 보 중 하나를 내세요')
for n in box:
    box_r = random.randint(0,2)
    ran = box[box_r]
    if ran == you:
        print ('''
        ==========
        컴퓨터: %s
        당신:%s
        비겼습니다.
        ----------
        컴퓨터 승률 {}
          당신 승률 {}
        =========='''%(ran,you))
        pass
    elif (ran == '가위' and you == '보') or (ran == '바위' and you == '가위') or (ran == '보' and you == '주먹'):
        print('''
        ==========
        컴퓨터: %s
        당신:%s
        당신이 졌습니다.
        ----------
        컴퓨터 승률 {}
          당신 승률 {}
        =========='''%(ran,you))
        pass
    elif (ran == '가위' and you == '주먹') or (ran == '바위' and you == '보') or (ran == '보' and you == '가위'):
        print('''
        ==========
        컴퓨터: %s
        당신:%s
        당신이 이겼습니다.
        ----------
        컴퓨터 승률 {}
          당신 승률 {}
        =========='''%(ran,you))
# Out:
# 가위, 바위, 보 중 하나를 내세요 가위
# ...
#         컴퓨터: 바위
#         당신:가위
#         당신이 졌습니다.
#         ----------
#         컴퓨터 승률 {}
#           당신 승률 {}
# ...
#
# ...
#         컴퓨터: 가위
#         당신:가위
#         비겼습니다.
#         ----------
#         컴퓨터 승률 {}
#           당신 승률 {}
# ...
#
# ...
#         컴퓨터: 보
#         당신:가위
#         당신이 이겼습니다.
#         ----------
#         컴퓨터 승률 {}
#           당신 승률 {}
# ...
