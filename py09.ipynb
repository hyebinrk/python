# %%
# !pip install -q -U google-genai

# %%
from google import genai
def aiai(text):
    client = genai.Client(api_key="AIza0SyA7965P7XSfyC2Y39dXZRQ8WfMqpNTceDtwBI")
    response = client.models.generate_content(model="gemini-2.0-flash", contents=text + ";단, 400자 이내 그리고 서술형으로 친절하게 알려줘")   
    answer = response.text
    print(answer)
    return answer
aiai("pandas에 대해서 알려줘")
# Out:
# ## Pandas, 데이터 분석을 위한 친절한 도구
#
# Pandas는 파이썬에서 데이터를 효율적으로 다루고 분석할 수 있도록 설계된 강력한 라이브러리입니다. 엑셀처럼 표 형태로 데이터를 관리하는 `DataFrame`과 1차원 배열 형태의 `Series`가 핵심 자료구조입니다.
#
# **DataFrame**은 행과 열로 구성되어 다양한 데이터 타입(숫자, 문자열, 날짜 등)을 담을 수 있습니다. 엑셀 시트와 유사하게 데이터를 정렬, 필터링, 그룹화하고 통계 분석을 수행하는 데 유용합니다.
#
# **Series**는 DataFrame의 열을 구성하는 기본 단위로, 1차원 배열처럼 인덱스와 값으로 이루어져 있습니다.
#
# Pandas는 CSV, 엑셀, SQL 데이터베이스 등 다양한 형식의 데이터를 읽고 쓸 수 있으며, 결측치 처리, 데이터 변환, 시각화 기능도 제공하여 데이터 분석 과정을 훨씬 편리하게 만들어줍니다. 데이터 분석, 머신러닝 등 다양한 분야에서 필수적인 도구라고 할 수 있습니다.
# '## Pandas, 데이터 분석을 위한 친절한 도구\n\nPandas는 파이썬에서 데이터를 효율적으로 다루고 분석할 수 있도록 설계된 강력한 라이브러리입니다. 엑셀처럼 표 형태로 데이터를 관리하는 `DataFrame`과 1차원 배열 형태의 `Series`가 핵심 자료구조입니다.\n\n**DataFrame**은 행과 열로 구성되어 다양한 데이터 타입(숫자, 문자열, 날짜 등)을 담을 수 있습니다. 엑셀 시트와 유사하게 데이터를 정렬, 필터링, 그룹화하고 통계 분석을 수행하는 데 유용합니다.\n\n**Series**는 DataFrame의 열을 구성하는 기본 단위로, 1차원 배열처럼 인덱스와 값으로 이루어져 있습니다.\n\nPandas는 CSV, 엑셀, SQL 데이터베이스 등 다양한 형식의 데이터를 읽고 쓸 수 있으며, 결측치 처리, 데이터 변환, 시각화 기능도 제공하여 데이터 분석 과정을 훨씬 편리하게 만들어줍니다. 데이터 분석, 머신러닝 등 다양한 분야에서 필수적인 도구라고 할 수 있습니다.\n'
