# %% [markdown]
# # 모듈

# %% [markdown]
# ## 모듈 만들기

# %%
#모듈 만들기
# def add(a, b):
#    return a + b
# def sub(a, b):
#    return a - b

# %%
import mod1
print(mod1.add(11,22))
print(mod1.sub(33,22))
# Out:
# 33
# 11

# %%
with open("mod2.py","w") as f:
    data = """def mul(a, b):
    return a * b
def div(a, b):
    return a / b"""
    f.write(data)

# %%
import mod2
print(mod2.mul(3,4))
print(mod2.div(8,4))
# Out:
# 12
# 2.0

# %%
import mod1,mod2
print(mod1.add(11,22))
print(mod1.sub(33,22))
print(mod2.mul(3,4))
print(mod2.div(8,4))
# Out:
# 33
# 11
# 12
# 2.0

# %%
# import mod1 as m1
# import mod2 as m2
import mod1 as m1, mod2 as m2
print(m1.add(11,22))
print(m1.sub(33,22))
print(m2.mul(3,4))
print(m2.div(8,4))
# Out:
# 33
# 11
# 12
# 2.0

# %%
from mod1 import add , sub
print(add(33,44)) #추천하지 않는 방법
# Out:
# 77

# %%
from mod2 import *
print(mul(4,5)) # 추천하지 않는 방법
# Out:
# 20

# %% [markdown]
# ## `__main__의 의미`

# %%
with open("mod1.py","a") as f:
    text = """\nprint(add(1,4))\nprint(sub(4,2))"""
    f.write(text)

# %% [markdown]
# 매직커멘드
# - %%bash : 리눅스
# - %%cmd : 윈도우

# %%
# %%cmd
# # %%bash : 우분투
# python mod1.py
# Out:
# Microsoft Windows [Version 10.0.26100.2894]
# (c) Microsoft Corporation. All rights reserved.
#
# B\code>
# d:\HB\code>python mod1.py
# 5
# 2
# __main__
# �� ���Ϸ� ������ �Ǿ����.
#
# d:\HB\code>

# %%
import mod1
dir(mod1)
# Out:
# 5
# 2
# mod1
# 전 모듈로 임포트 되었어요.
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'sub']

# %%
with open('mod1.py','a')as f:
    content = "\nprint(__name__)"
    f.write(content)

# %%
with open("sam.py","w",encoding="utf-8") as f:
    data = '''
import requests as req
url = "https://finance.naver.com/sise/sise_market_sum.naver"
web = req.get(url)
html = web.text
f1 = html.find("삼성전자")
html[f1:f1+100].find('<td class="number">')
where = html[f1:f1+100].find('<td class="number">')
print('삼성전자 : '+html[f1:f1+100][where:50].replace('<td class="number">',"").replace('</td>',"").replace("\n","")+"원")
'''
    f.write(data)
f.close()

# %%
# %%cmd
# python sam.py
# Out:
# Microsoft Windows [Version 10.0.26100.2894]
# (c) Microsoft Corporation. All rights reserved.
#
# B\code>python sam.py
#   File "d:\HB\code\sam.py", line 9
# lass="number">',"").replace('</td>',"").replace("eplace('<td c
#                                                            ^
# al (detected at line 9)ed string liter
# d:\HB\code>

# %% [markdown]
# ## 클래스나 변수등을 포함한 모듈

# %%
with open("mod3.py","w") as f:
    text = """PI = 3.141592\n\nclass Math:\n\tdef solv(self,r):\n\t\treturn PI * (r**2)\n\ndef add(a,b):\n\treturn a+b"""
    f.write(text)

# %% [markdown]
# - CMD에서 set PYTHONPATH=D:\hb\code\mymod
# - PS에서 $env.PYTHONPATH=D:\hb\code\mymod

# %%
import mod3
# 변수
print(mod3.PI)
# 클래스
a = mod3.Math()
print(a.solv(10))
# 함수
print(mod3.add(mod3.PI,4.4))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import mod3
#       2 # 변수
#       3 print(mod3.PI)
#
# ModuleNotFoundError: No module named 'mod3'

# %% [markdown]
# ## 다른 디렉터리에 있는 모듈 불러오는 방법

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\DLLs',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313',
#  '',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\Pythonwin',
#  'D:\\hb\\code\\mymod>']

# %%
sys.path.append('D:\\hb\\code\\mymod>') # 초기화하면 사라짐
sys.path
# Out:
# ['C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\DLLs',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313',
#  '',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\Pythonwin',
#  'D:\\hb\\code\\mymod>',
#  'D:\\hb\\code\\mymod>',
#  'D:\\hb\\code\\mymod>']

# %%
# !pip install python-dotenv
# !python.exe -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 11.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# ...

# %%
from dotenv import load_dotenv
import os

# .env 파일 로드
load_dotenv()

SKEY = os.getenv("SECRET_KEY")
print(SKEY)
DBUG = os.getenv("DEBUG")
print(DBUG)
TEST = os.getenv("TEST")
print(TEST)
# Out:
# myphone(010-030405-020628)
# http://www.google.com
# 이게될까?? 모르겠어요!

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
from dotenv import load_dotenv

load_dotenv()
client_id =  os.environ.get("MY_ID")
client_secret =  os.environ.get("MY_SECRET")


encText = urllib.parse.quote("속보")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText + '&display=5&start=1&sort=sim'# JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Feb 2025 14:40:25 +0900",
# 	"total":2094819,
# 	"start":1,
# 	"display":5,
# 	"items":[
# 		{
# 			"title":"[<b>속보<\/b>] '불법 촬영' 황의조 1심서 징역형 집행유예",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20250214099100004?input=1195m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0015213954?sid=102",
# 			"description":"",
# 			"pubDate":"Fri, 14 Feb 2025 14:35:00 +0900"
# 		},
# 		{
# 			"title":"[<b>속보<\/b>] ‘불법 촬영’ 황의조, 1심 징역 1년·집유 2년",
# 			"originallink":"https:\/\/www.chosun.com\/national\/court_law\/2025\/02\/14\/ISPHZCGTFZHJTGW2XEWTIPUYHA\/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/023\/0003888097?sid=102",
# 			"description":"‘불법 촬영’ 황의조, 1심 징역 1년·집유 2년",
# 			"pubDate":"Fri, 14 Feb 2025 14:36:00 +0900"
# 		},
# 		{
# 			"title":"[<b>속보<\/b>] '불법 촬영' 황의조 1심서 징역형 집행유예",
# 			"originallink":"https:\/\/www.hankyung.com\/article\/2025021461047",
# ...

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
from dotenv import load_dotenv
import json

load_dotenv()
client_id =  os.environ.get("MY_ID")
client_secret =  os.environ.get("MY_SECRET")


encText = urllib.parse.quote("속보")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText + '&display=5&start=1&sort=sim'# JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    data = json.loads(result)
    ldata = data['items']
    for n in ldata:
        print(n['title'].replace('<b>','').replace('</b>',''))
        print(n['description'])
        print(n['originallink'])
else:
    print("Error Code:" + rescode)
# Out:
# [속보]국민의힘 윤리위, 尹 징계 않기로
# 국민의힘 윤리위, 尹 징계 않기로 ※CBS노컷뉴스는 여러분의 제보로 함께 세상을 바꿉니다. 각종 비리와 부당대우, 사건사고와 미담 등 모든 얘깃거리를 알려주세요.이메일 : 카카오톡 : @노컷뉴스사이트 : https...
# https://www.nocutnews.co.kr/news/6292989?utm_source=naver&utm_medium=article&utm_campaign=20250213035336
# [속보]박지원, 홍장원 인사청탁 부정 “청탁자는 주영대사 역임 前 간부...
# 박지원 더불어민주당 의원이 13일 “홍장원 전 국가정보원 1차장은 정보위 회의에서 첫 대면했다”라면서 홍 전 차장이 자신에게 인사 청탁을 했다는 의혹을 전면 부인했다. 박 의원은 이날 자신의 페이스북에 글을 올려...
# https://www.munhwa.com/news/view.html?no=2025021301039910289018
# [속보] KT, 올해 2500억 규모 자사주 소각
# KT는 올해 약 2500억원 규모의 자사주를 소각한다고 13일 밝혔다. 소각할 주식은 보통주 553만7099주다. KT는 지난해 11월 발표한 기업가치 제고 계획(밸류업 프로그램)을 발표하며 연결 자기자본이익률(ROE) 목표를 9...
# https://www.newsis.com/view/NISX20250213_0003064022
# [속보] 국힘 윤리위, 尹 제명·탈당 권유 등 징계 않기로 결정
# 국민의힘 중앙윤리위원회가 한동훈 전 대표의 요구로 시작된 윤석열 대통령 징계 절차 종결을 선언하고 제명·탈당 권유 등 징계 조치를 하지 않기로 결론을 내렸다. 13일 여의도 당사에서 윤리위 회의를 마친 여상원 당...
# https://www.busan.com/view/busan/view.php?code=2025021315294691312
# [속보] '이재명 습격' 60대 남성 징역 15년 확정
# ...

# %%
# !pip install qrcode

# %%
import qrcode

def qrcode_maker(text,filename='qr.png'):
    qr = qrcode.make(text)
    qr.save(filename)

qrcode_maker('안녕하세요 반갑습니다❗🍕')
qrcode_maker('www.naver.com','naver.png')

# %%
from IPython.display import display , HTML
from PIL import Image

image_path = "qr.png"
img = Image.open(image_path)
htmlcode = "<img src='qr.png' width=150>"
display(HTML(htmlcode))
# display(img)
# Out:
# <img src='qr.png' width=150>

# %%
positive_words = ["좋아","행복","멋져", "최고","사랑해"]
negative_words = ["싫어","화나","짜증","별로","나빠"]

a = input("당신의 기분을 한 문장으로 표현해주세요.")
mood = a.split()

for x in range(0,7):
    if x in mood :
        print('기분이 좋아보이네요')
# Out:
# 당신의 기분을 한 문장으로 표현해주세요. 멋져
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       4 a = input("당신의 기분을 한 문장으로 표현해주세요.")
#       5 mood = a.split()
# ----> 7 for x in range(positive_words):
#       8     if x in mood :
#       9         print('기분이 좋아보이네요')
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
# elif for y in range(negative_words):
    #     if y in mood:
    #         print('기분이 나빠보이네요')
    # else:
    #     print('평범한 하루네요')

# %%
a = ["가","나"]
for i in range(a):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 a = ["가","나"]
# ----> 2 for i in range(a):
#       3     print(i)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# # 패키지

# %% [markdown]
# ## 패키지 만들기

# %%
# %%cmd
# set PYTHONPATH=D:\HB\\code\game

# %%
# 테스트 1 명시적이다. 그렇지만 길다.
import game.sound.echo
import game.graphic.render
game.sound.echo.echo_test()
game.graphic.render.render_test()
# Out:
# 에코
# 랜더링

# %%
# 짧지만 중복의 위험이 있다. 그리고 명시적이진 않다(별칭을 썼기 때문에)
from game.echo_v import echo_test as ev
from game.echo import echo_test as e
ev()
e()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 짧지만 중복의 위험이 있다. 그리고 명시적이진 않다(별칭을 썼기 때문에)
# ----> 2 from game.echo_v import echo_test as ev
#       3 from game.echo import echo_test as e
#       4 ev()
#
# ModuleNotFoundError: No module named 'game.echo_v'

# %%
# __init__.py 를 사용하기
import game
print(game.VERSION)
game.print_version_info() #이미 프린트가 들어가있기 때문에 print함수를 쓰지않아도 출력됨
# Out:
# 3.6
# The version of this game is 3.6

# %%
# __init__.py 은 한번만 로드됨
import game

# %%
# __init__.py 는 패키지내에 내 모듈을 미리 import 할 수 있다.
game.render_test()
# Out:
# 랜더링

# %%
import game.graphic

# %%
game.graphic.print_version_info()
# Out:
# The version of this fraphic of game is 3.7

# %%
# _all__ 사용하기
from game.graphic import *
# Out:
# Initializing Game...

# %%
echo.echo_test()
# Out:
# 비디오에코

# %%
# relative 패키지
from game.graphic.render import render_test
# Out:
# Initializing Game...

# %%
#비디오 에코가 아닌 사운드 에코 호출
render_test()
# Out:
# 랜더링
# 에코

# %% [markdown]
# # 예외처리

# %% [markdown]
# ## 오류발생
# - 오타
# - 존재하지 않는 파일을 지정하거나 사용할 때
# - 문법 오류
# - 수학적오류
# - 인덱스 오류
# ## 오류 예외 처리 기법
# - try-except 문
# - try-finally 문
# - 여러개의 오류 처리
# - try-else 문

# %%
#없는파일
# f = open('뜬금파일','r')
# FileNotFoundError: [Errno 2] No such file or directory: '뜬금파일'

# %%
# 4/0
# ZeroDivisionError: division by zero

# %%
# a = [1,2,3]
# print(a[7])
# IndexError: list index out of range

# %%
# 테스트 1

try:
    f = open('뜬금파일','r')
    
except FileNotFoundError as e:
    if e:
        print('없는거찾지마, 혼자있고싶어')
    print(e)
finally:
    print('코드 작성을 마칩니다.')
# Out:
# 없는거찾지마, 혼자있고싶어
# [Errno 2] No such file or directory: '뜬금파일'
# 코드 작성을 마칩니다.

# %%
# 지정한 이름의 예외처리 as로 별칭 가능
try:
    4/0
except ZeroDivisionError as e:
    print('0으로 나눌 수 없어요',e)
# Out:
# 0으로 나눌 수 없어요 division by zero

# %%
# try-except-finally 3단계도 가능(2단계는 필수. try만 쓸 수는 없음), 
# FINALLY는 에러가 나도 무조건 처리하는 것(여기서는 파일 닫기)
try:
    f = open('foo.txt','w')
    f.write(4/0)
except:
    print("0으로 나누지 마세요")
finally:
    f.close()
# Out:
# 0으로 나누지 마세요

# %%
# 테스트 해볼 것 2개 이상의 오류를 동일하게 처리
try:
    a = 1,2
    print(a[512])
    4/0
except (ZeroDivisionError,IndexError) as e:
    print(e)
# Out:
# tuple index out of range

# %%
# try-else 문
try:
    age = int(input("나이를 입력하세요"))
except:
    print("입력이 정확하지 않습니다.")
else:            # else는 파이썬에만 있다(오류가 없을때만 실행하는것)
    if age <= 18:
        print('미성년자는 출입금지')
    else:
        print('환영합니다.')
finally:
    print('='*3+'\n분석끝')      #무조건 나와야하는 것

# 파이썬에만 else가 있는 이유는 굳이 없어도 되기때문. 저걸 try에 다 넣어줄 수 있다.
# Out:
# 나이를 입력하세요 22
# 환영합니다.
# ===
# 분석끝

# %%
try:
    age = int(input("나이를 입력하세요"))
    if age <= 18:
        print('미성년자는 출입금지')
    else:
        print('환영합니다.')
except:
    print("입력이 정확하지 않습니다.")
finally:
    print('='*3+'\n분석끝')
# Out:
# 나이를 입력하세요 22
# 환영합니다.
# ===
# 분석끝

# %%
# 오류 회피하기
try:
    print('반가워')
    f = open('없는파일','r') # 이 에러지점부터 이후로는 처리 안 함
    4/0
    print('안녕')
except:
    pass
# Out:
# 반가워

# %%
# 오류 일부러 발생시키기 (클래스 상속기반)
class Bird:
    def fly(self):
        raise NotImplementedError

class Eagle(Bird):
    # pass
    def fly(self):
        print('난 독수리다')

eagle = Eagle()
eagle.fly()
# Out:
# 난 독수리다

# %%
# 예외 만들기
class MyError(Exception):
    pass

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

# %%
say_nick('바보')
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 say_nick('바보')
#
# Cell In[69], line 3, in say_nick(nick)
#       1 def say_nick(nick):
#       2     if nick == '바보':
# ----> 3         raise MyError()
#       4     print(nick)
#
# MyError:

# %%
try:
    say_nick('천사')
    say_nick('바보')
except MyError as e:
    print('욕하지마. 나 바보 아니야',e)
# Out:
# 천사
# 욕하지마. 나 바보 아니야 욕하지마 그래도 사람은 착해

# %%
class MyError(Exception):
    def __str__(self):
        return "욕하지마 그래도 사람은 착해"
