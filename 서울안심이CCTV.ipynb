# %%
import matplotlib.font_manager as fm
from matplotlib import rc
import matplotlib.pyplot as plt
plt.rc('font',family="맑은 고딕")
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# findfont: Font family '맑은 고딕' not found.
# ...

# %%
import pandas as pd
file_path = "./ref/서울시안심이CCTV연계현황.csv"
ori = pd.read_csv(file_path,encoding='CP949')
ori.sample(5)
# Out:
#        자치구                    안심 주소       위도        경도  CCTV 수량       수정 일시
# 17167  양천구  스마007 신은초교(신정이펜2로30) 회전  37.5136  126.8318        1  2022-12-01
# 28594  성동구        P059_(회전)_남양유업 주변  37.5642  127.0280        1  2022-12-01
# 72772  강북구   [3190][방범-미아-137](어안M)  37.6251  127.0255        1  2022-12-01
# 47553  도봉구                 방학1C2021  37.6687  127.0419        1  2022-12-01
# 11293  은평구      녹번동 218 명성학원 건너편 /2  37.6013  126.9316        1  2022-12-01

# %%
ori = ori.rename(columns={'자치구':'location'})['location']
ori = ori.value_counts().reset_index()
ori = ori.set_index('location')
ori
# Out:
#           count
# location
# 강남구        7007
# 관악구        5366
# 서초구        5060
# 은평구        4111
# 광진구        4091
# 구로구        4050
# 성동구        4036
# 성북구        3943
# 양천구        3845
# 중랑구        3471
# 서대문구       3223
# 강서구        3210
# 강동구        3191
# 송파구        3094
# 영등포구       2899
# 강북구        2858
# 동대문구       2857
# 금천구        2725
# 노원구        2655
# 동작구        2650
# 마포구        2450
# 중구         2336
# 종로구        1930
# 도봉구        1598
# 용산구        1078

# %%
ori_barh = ori['count'].sort_values().plot(x = 'local', y = 'count', kind='barh', figsize=(13,9), ylabel='구', xlabel='CCTV 수', title = '서울 안심이 CCTV 설치현황')

plt.show()
# Out:
# findfont: Font family 'D2Coding' not found.
# findfont: Font family 'D2Coding' not found.
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'D2Coding' not found.
# ...

# %% [markdown]
# - 강남구가 압도적으로 많고 그 다음으로 관악구, 서초구가 많고 설치 수의 편차가 구마다 큰 것으로 보인다.
# - 가장 많은 강남구와 용산구의 CCTV 설치 수는 약 7000대의 차이가 난다.

# %%
p_path = "./ref/등록인구20250312093029.csv"
population_read = pd.read_csv(p_path)
population_read
# Out:
#     동별(1)  동별(2) 2024 4/4 2024 4/4.1 2024 4/4.2 2024 4/4.3 2024 4/4.4  \
# 0   동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1   동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2      합계     소계  4482063    9597372    4619963    4977409    9331828
# 3      합계    종로구    72166     149608      71365      78243     138336
# 4      합계     중구    64995     131214      62924      68290     120544
# 5      합계    용산구   103241     217194     104540     112654     203854
# 6      합계    성동구   131953     281289     135575     145714     273669
# 7      합계    광진구   169931     348652     166045     182607     331963
# 8      합계   동대문구   172840     358603     173000     185603     338735
# 9      합계    중랑구   188651     385349     187910     197439     379274
# 10     합계    성북구   196485     435037     206945     228092     421560
# 11     합계    강북구   143063     289374     138730     150644     283597
# ...
