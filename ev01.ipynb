# %%
# 파이썬 if
# 0,1,2,3,4 X
# 가라, 마라, 오라 X
# True, False O

fruit=["apple","orange","banana"]
fruit1=["orange","banana"]
fruit2=["apple","orange","banana"]
fruit3=["apple","orange","banana"]
fruit4=["apple","orange","banana"]
fruit5=["apple","orange","banana"]

print(fruit[0])
print(fruit[1])
print(fruit[2])
# Out:
# apple
# orange
# banana

# %%
if True : # 벽에 있는 스위치(조건은 두종류만 들어가야 함)
    print("조건이 맞아요.")
# Out:
# 조건이 맞아요.

# %%
if 2>1 : #벽에 있는 스위치
    print("조건이 맞아요.")
# Out:
# 조건이 맞아요.

# %%
if 2<1 : #벽에 있는 스위치
    print("조건이 맞아요.")

# %%
if fruit[0] == "apple" :
    print("과일이 맞아요.")
# Out:
# 과일이 맞아요.

# %%
if "apple" in fruit :
    print("과일이 맞아요.")
# Out:
# 과일이 맞아요.

# %%
if "kiwi" not in fruit :
    print("과일이 맞아요.")
# Out:
# 과일이 맞아요.

# %%
if "apple" in fruit:
    print("사과가 있어요.")
if "apple" not in fruit:
    print("사과가 없어요.")
# Out:
# 사과가 있어요.

# %%
if "apple" in fruit:
    print("사과가 있어요.")
else:
    print("사과가 없어요.")
# Out:
# 사과가 있어요.

# %%
if "apple" in fruit1:
    print("fruit1에 사과가 있어요.")
elif "apple" in fruit2:
    print("fruit2에사과가 없어요.")
elif "apple" in fruit3:
    print("fruit3에 사과가 없어요.")
elif "apple" in fruit4:
    print("fruit4에 사과가 없어요.")
elif "apple" in fruit5:
    print("fruit5에 사과가 없어요.")
# Out:
# 사과가 없어요.

# %%
if "apple" in fruit1:
    print("사과가 있어요.")
elif "apple" in fruit2:
    print("사과가 없어요.")
elif "apple" in fruit2:
    print("사과가 없어요.")
elif "apple" in fruit2:
    print("사과가 없어요.")
elif "apple" in fruit2:
    print("사과가 없어요.")
